# %%
# %pylab inline
import matplotlib.pyplot as plt
from scipy.signal import fftconvolve, lfilter, firwin
import numpy as np
import scipy as sp
y = np.array([
0.00, 33.11, 3.64, 11.81, 11.67, -1.44, -2.24, 11.49, -7.02, -9.55, 3.11, 120.66, 257.48, 285.91, 177.22, 155.60, 181.02, 184.79, 210.86, 307.71, 397.24, 496.91, 656.07, 582.42, 633.94, 457.43, 592.68, 665.72, 793.34, 860.33, 636.11, 748.02, 756.80, 664.05, 783.33, 828.44, 833.36, 1066.32, 881.03, 917.61, 879.65, 854.38, 889.69
])
plt.plot(range(5 * len(y))[::5], y)

def f1(x):
    return 26.79204772 /5 * x - 167.17486258 / 5

plt.plot(range(5 * len(y))[::5], [f1(x1) for x1 in range(5 * len(y))[::5]])

plt.show()
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
x = range(len(y))
cutoff = 10
print(numpy.polyfit(x[cutoff:], y[cutoff:], 1))
# Out:
# [  28.2959492  -167.23316399]

# %%
y = np.array([
.00, -11.92, 2.14, 2.03, 0.23, -1.15, 1.07, -0.11, -1.12, -5.64, 0.17, 0.66, 0.09, -15.43, -263.47, -417.87, -484.73, -475.65, -518.45, -602.37, -509.51, -624.84, -733.63, -627.51, -717.92, -823.32, -857.29, -834.76, -845.53, -987.39, -839.98, -892.46, -1014.31, -887.70, -935.69, -1037.18, -1046.44, -986.67, -955.01, -840.48, -1149.28])
plt.plot(range(5 * len(y))[::5], y)

def f1(x):
    return -34 /5 * x + 176 / 5

plt.plot(range(5 * len(y))[::5], [f1(x1) for x1 in range(5 * len(y))[::5]])

plt.show()

# %%
x = range(len(y))
cutoff = 10
print(numpy.polyfit(x[cutoff:], y[cutoff:], 1))
# Out:
# [ -34.05378226  176.37842742]
